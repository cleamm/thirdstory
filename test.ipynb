# %% [markdown]
# <a href="https://colab.research.google.com/github/cleamm/thirdstory/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/데이콘
# Out:
# /content/drive/MyDrive/데이콘

# %%
ls
# Out:
# 본선/                 dnnsub.csv               submission_ver15.csv
# automl_another        dnn_success.ipynb        submission_ver1.csv
# autoML.ipynb          LGBMbaseline.csv         submission_ver2.csv
# baseline-1.csv        logs.log                 submission_ver3.csv
# baseline-2.csv        nn_minmax1.csv           submission_ver4.csv
# baseline-3.csv        nn_minmax.csv            submission_ver5.csv
# baseline-4.csv        nn_minmax_ohe1.csv       submission_ver5-origin.csv
# baseline.csv          nn_minmax_ohe.csv        submission_ver6.csv
# competition_data.zip  onehotencoding-nn.ipynb  submission_ver7.csv
# dacon.ipynb           pipeline_code.ipynb      submission_ver8.csv
# datapre.ipynb         pipeline-linear.csv      submission_ver9.csv
# datatest.ipynb        sample_submission.csv    test.csv
# default.ipynb         submission_editver.csv   tp.csv
# DNN.ipynb             submission_ver10.csv     train.csv
# ...

# %%
import pandas as pd
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    index   Q1   Q2   Q3   Q4   Q5   Q6   Q7   Q8   Q9  ...  engnat  age  hand  \
# 0      0  1.0  5.0  5.0  5.0  1.0  4.0  5.0  5.0  1.0  ...     1.0   20   2.0
# 1      1  4.0  4.0  4.0  4.0  4.0  5.0  4.0  4.0  3.0  ...     1.0   49   1.0
# 2      2  4.0  5.0  5.0  4.0  3.0  5.0  5.0  5.0  4.0  ...     2.0   43   1.0
# 3      3  4.0  4.0  4.0  2.0  4.0  3.0  3.0  5.0  3.0  ...     1.0   17   2.0
# 4      4  4.0  4.0  4.0  4.0  3.0  3.0  4.0  2.0  3.0  ...     2.0   18   2.0
#
#    religion  orientation  voted  married  familysize  ASD  nerdiness
# 0      12.0          4.0    2.0      1.0         4.0  2.0          1
# 1       2.0          1.0    1.0      2.0         4.0  2.0          1
# 2       2.0          2.0    2.0      3.0         4.0  2.0          1
# 3       1.0          1.0    2.0      1.0         2.0  2.0          1
# 4      12.0          1.0    2.0      1.0         1.0  2.0          0
#
# [5 rows x 70 columns]

# %%
train.describe()
# Out:
#               index            Q1            Q2            Q3            Q4  \
# count  15000.000000  14959.000000  14931.000000  14950.000000  14929.000000
# mean    7499.500000      3.972859      4.065702      4.222809      3.795499
# std     4330.271354      1.095914      1.169681      1.023335      1.219940
# min        0.000000      1.000000      1.000000      1.000000      1.000000
# 25%     3749.750000      3.000000      4.000000      4.000000      3.000000
# 50%     7499.500000      4.000000      4.000000      5.000000      4.000000
# 75%    11249.250000      5.000000      5.000000      5.000000      5.000000
# max    14999.000000      5.000000      5.000000      5.000000      5.000000
#
#                  Q5            Q6            Q7            Q8            Q9  \
# count  14962.000000  14952.000000  14924.000000  14952.000000  14944.000000
# mean       3.856503      3.676364      4.183262      3.879013      3.915418
# ...
